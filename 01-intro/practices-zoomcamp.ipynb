# %%
<h1 style="color:#4CAF50;"> Machine Learning Project Practices-Zoomcamp</h1>
<h3 style="color:#2196F3;">Hello, <em>Agyeman-Tee</em>!</h3>
<p style="color:#FF9800;">Welcome to Machine Learning </p>
